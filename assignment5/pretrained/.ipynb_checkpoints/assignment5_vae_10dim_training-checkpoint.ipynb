# %% [markdown]
# # Dimensionality Reduction and Generative Modelling

# %%
# Imports
import numpy as np
import theano
import time
import matplotlib
import matplotlib.pyplot as plt
from utils.data import load_mnist_data
from utils.pca import pca
from exercise_helper import load_data,plot_2d_proj,plot_act_rec
import six.moves.cPickle as pickle

theano.config.floatX = "float32"
rng_np = np.random.RandomState(23455)

# %% [markdown]
# ## Variational Auto-Encoder (VAE)
#
# Variational auto-encoder (abbrv. VAE, Kingma and Welling - 2013) is a generative model. Like an auto-encoder, the VAE projects input data into a latent space and then reconstructs it back. But instead of mapping the data to a single point in the embedding space (now we will refer to this as the *latent space*) it maps it to a distribution.
#
# In the VAE we map each datapoint to a mean and standard deviation of a multivariate Gaussian (the number of dimensions of this Gaussian is the dimension of our latent space). We then try to 'overlap' a standard Gaussian (zero mean and unit variance, with same dimensions as the latent space) over this distribution of datapoints. This is what minimizing the KL-Divergence achieves.
#
# Now, to get a re-construction, we just sample from the standard gaussian and project the sample back into the original data space (To the space of MNIST images, in our case). We also, optimize the parameters of the model to maximize the 'reconstruction' or minimize the 'difference' between the samples and the input image.
#
# So, in the VAE we have a sum of two terms in the cost function:
# 1. The KL-Divergence term (the 'overlap' term discussed above).
# 2. The Reconstruction term (also referred to as the 'reconstruction' term above).
#
# Contrast this with the auto-encoder which just has the 'reconstruction' as the cost function.
#
# ### Drawing samples from the VAE
#
# Recall that the VAE is a generative model, so we must be able to draw samples from it. Minimizing the 'overlap' term in the VAE cost allows us to approximate a complex multivariate normal (which can be difficult/impossible to sample from) to a standard multivariate normal (easy to sample from). After training the VAE, we should then be able to sample from the standard multivariate normal and project them to data space to get samples of (in this case) MNIST images. So, we have a generative model !
#
# Now that we have an intuitive understanding of the VAE, let's implement it.

# %%
datasets = load_data('mnist.pkl.gz', train_size = 50000,binarize="stochastic")
train_x, train_y = datasets[0]
valid_x, valid_y = datasets[1]
test_x, test_y = datasets[2]
# Out:
# ***** Loading data *****

# %%
def gradient_updates_Adam(cost, params, learning_rate,eps = 1e-8,beta1 = 0.9,beta2 = 0.999):
    # Function to return an update list for the parameters to be updated
    
    # cost: MSE cost Theano variable
    # params :  parameters coming from hidden and output layers
    # learning rate: learning rate defined as hyperparameter
    
    # Outputs:
    # updates : updates to be made and to be defined in the train_model function. 
    updates = []
    for param in params:
             
            t = theano.shared(1)
            s = theano.shared(param.get_value(borrow=True)*0.)
            r = theano.shared(param.get_value(borrow=True)*0.)
            updates.append((s, beta1*s + (1.0-beta1)*T.grad(cost, param) ))
            updates.append((r, beta2*r + (1.0-beta2)*(T.grad(cost, param)**2) ))
            s_hat =  s/(1-beta1**t)
            r_hat =  r/(1-beta2**t)
            updates.append((param, param - learning_rate*s_hat/(np.sqrt(r_hat)+eps) ))
            updates.append((t, t+1)) 

    return updates

# %%
# implementing the VAE in theano
# similar network architecture to (Kingma and Welling 2013)
import numpy as np
import theano
import theano.tensor as T
from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams

input = T.fmatrix("input") # symbolic float32 matrix, eventually will have (minibatch x 784)
learning_rate = T.fscalar("learning_rate") # float32 learning rate.
mbidxs = T.lvector("mbidxs")

# autoencoder layer dimensions
latent_dim = 10
dims = [784, 500, latent_dim, 500, 784]

uniform_lim = lambda n_in,n_out : (-np.sqrt(6.0/(n_in+n_out)), np.sqrt(6.0/(n_in+n_out))) 

W1 = theano.shared(rng_np.uniform(*uniform_lim(dims[0], dims[1]), size=dims[0:2]), borrow=True, name="W1")
W2_mu = theano.shared(rng_np.uniform(*uniform_lim(dims[1], dims[2]), size=dims[1:3]), borrow=True, name="W2_mu")
W2_logvar = theano.shared(rng_np.uniform(*uniform_lim(dims[1], dims[2]), size=dims[1:3]), borrow=True, name="W2_logvar")

W3 = theano.shared(rng_np.uniform(*uniform_lim(dims[2], dims[3]), size=dims[2:4]), borrow=True, name="W3")
W4 = theano.shared(rng_np.uniform(*uniform_lim(dims[3], dims[4]), size=dims[3:5]), borrow=True, name="W4")

b1 = theano.shared(np.zeros((dims[1],)), borrow=True, name="b1")
b2_mu = theano.shared(np.zeros((dims[2],)), borrow=True, name="b2_mu")
b2_logvar = theano.shared(np.zeros((dims[2],)), borrow=True, name="b2_logvar")

b3 = theano.shared(np.zeros((dims[3],)), borrow=True, name="b3")
b4 = theano.shared(np.zeros((dims[4],)), borrow=True, name="b4")

relu = T.nnet.relu
sigmoid = T.nnet.sigmoid
tanh = T.tanh

srng = RandomStreams(seed=1234)
x1     = tanh(T.dot(input, W1) + b1)
mu     = T.dot(x1, W2_mu) + b2_mu
logvar = T.dot(x1, W2_logvar) + b2_logvar
z = mu + srng.normal(logvar.shape)*T.exp(0.5*logvar)
x1_rec = tanh(T.dot(z, W3) + b3)
x_rec  = sigmoid(T.dot(x1_rec, W4) + b4)

cost_rec = -T.nnet.binary_crossentropy(x_rec, input).sum(axis=1)
cost_KL   = 0.5*T.sum(1 + logvar - mu**2 - T.exp(logvar), axis=1)
lower_bound = T.mean(cost_KL + cost_rec)
cost = -lower_bound # minimize -ve of lower bound

params = [W1,W2_mu,W2_logvar,W3,W4,b1,b2_mu,b2_logvar,b3,b4]
updates = gradient_updates_Adam(cost,params,learning_rate)


vae_train = theano.function(
        inputs = [mbidxs, learning_rate], 
        outputs = [cost, x_rec, mu, logvar, cost_KL, cost_rec],
        updates = updates,
        givens = {
            input : train_x[mbidxs,:],
        }
    )


vae_predict = theano.function(
        inputs = [input],
        outputs = [cost, x_rec, mu, logvar]
    )


vae_generate = theano.function(
        inputs = [z],
        outputs = x_rec
    )

# %% [markdown]
# ** TODO : **
#  - remove prediction returns
#  - error -> cost

# %%
mb_size = 500
epochs = 500
lrate = 0.0001
train_errors = []
valid_errors = []
train_start_time = time.time()

train_size = len(train_y.eval()) 
training_idxs = np.arange(train_size)

print("***** training started  *****")

for epoch in range(epochs):
    
    rng_np.shuffle(training_idxs)
                
    try:    
        t_minib_errors = []
        t_minib_cost_kl = []
        t_minib_cost_rec = []
        start_time = time.time()
        
        for batch_startidx in range(0, train_size, mb_size):

            mini_batch = training_idxs[batch_startidx:batch_startidx+mb_size]
            
            rec_error, rec, train_mu, train_logvar, cost_kl, cost_rec  = vae_train(
                    mbidxs = np.asarray(mini_batch).astype(np.int32),
                    learning_rate=lrate)
            
            t_minib_errors.append(rec_error)
            t_minib_cost_kl.append(cost_kl)
            t_minib_cost_rec.append(cost_rec)

        valid_rec_error, valid_rec, valid_mu, valid_logvar = vae_predict(input = valid_x.get_value())
        
        
        train_errors.append(np.mean(t_minib_errors))
        valid_errors.append(np.mean(valid_rec_error))
        print("epoch={:<3d} -- train_error={:>6.4f} -- valid_error={:>6.4f} -- cost(Rec,KL)=({:>6.4f},{:>6.4f}) -- time={:>5.3f}".format(epoch, train_errors[-1], valid_errors[-1], np.mean(t_minib_cost_rec),np.mean(t_minib_cost_kl),time.time()-start_time))    
    
    
    except KeyboardInterrupt as e:
        print("***** stopping *****")
        break
# Out:
# ***** training started  *****
# epoch=0   -- train_error=390.8117 -- valid_error=271.1038 -- cost(Rec,KL)=(-359.4846,-31.3271) -- time=18.460
# epoch=1   -- train_error=247.9519 -- valid_error=228.5640 -- cost(Rec,KL)=(-222.3066,-25.6453) -- time=18.015
# epoch=2   -- train_error=218.0051 -- valid_error=206.0279 -- cost(Rec,KL)=(-198.3750,-19.6301) -- time=18.382
# epoch=3   -- train_error=200.4578 -- valid_error=191.8797 -- cost(Rec,KL)=(-180.8141,-19.6437) -- time=17.034
# epoch=4   -- train_error=188.5791 -- valid_error=182.9076 -- cost(Rec,KL)=(-168.8633,-19.7159) -- time=17.146
# epoch=5   -- train_error=180.1518 -- valid_error=175.9921 -- cost(Rec,KL)=(-160.9393,-19.2125) -- time=16.178
# epoch=6   -- train_error=174.2155 -- valid_error=170.9019 -- cost(Rec,KL)=(-155.3216,-18.8940) -- time=15.652
# epoch=7   -- train_error=169.7199 -- valid_error=166.1282 -- cost(Rec,KL)=(-151.1526,-18.5673) -- time=16.893
# epoch=8   -- train_error=166.7207 -- valid_error=162.4869 -- cost(Rec,KL)=(-147.9503,-18.7703) -- time=17.662
# epoch=9   -- train_error=162.4585 -- valid_error=159.5096 -- cost(Rec,KL)=(-143.7752,-18.6834) -- time=15.912
# epoch=10  -- train_error=158.8465 -- valid_error=156.6206 -- cost(Rec,KL)=(-140.3930,-18.4534) -- time=16.007
# epoch=11  -- train_error=156.2928 -- valid_error=154.3925 -- cost(Rec,KL)=(-137.9032,-18.3896) -- time=15.952
# epoch=12  -- train_error=154.2990 -- valid_error=152.8999 -- cost(Rec,KL)=(-135.9394,-18.3596) -- time=16.994
# epoch=13  -- train_error=153.5432 -- valid_error=152.5676 -- cost(Rec,KL)=(-135.1138,-18.4294) -- time=16.243
# epoch=14  -- train_error=152.8381 -- valid_error=150.3444 -- cost(Rec,KL)=(-134.4385,-18.3996) -- time=16.611
# epoch=15  -- train_error=150.4414 -- valid_error=149.0814 -- cost(Rec,KL)=(-132.3464,-18.0950) -- time=16.515
# epoch=16  -- train_error=149.3270 -- valid_error=148.9576 -- cost(Rec,KL)=(-131.4382,-17.8888) -- time=16.476
# epoch=17  -- train_error=149.0937 -- valid_error=147.4304 -- cost(Rec,KL)=(-131.2024,-17.8913) -- time=15.419
# epoch=18  -- train_error=148.3038 -- valid_error=147.1451 -- cost(Rec,KL)=(-130.5720,-17.7318) -- time=16.752
# epoch=19  -- train_error=147.4409 -- valid_error=146.9390 -- cost(Rec,KL)=(-129.8936,-17.5473) -- time=15.422
# epoch=20  -- train_error=146.7922 -- valid_error=145.5482 -- cost(Rec,KL)=(-129.3409,-17.4513) -- time=16.965
# epoch=21  -- train_error=146.0638 -- valid_error=145.7212 -- cost(Rec,KL)=(-128.6635,-17.4003) -- time=17.109
# epoch=22  -- train_error=146.1120 -- valid_error=145.5815 -- cost(Rec,KL)=(-128.7685,-17.3436) -- time=17.336
# epoch=23  -- train_error=146.0602 -- valid_error=146.1483 -- cost(Rec,KL)=(-128.7059,-17.3543) -- time=17.823
# epoch=24  -- train_error=145.8091 -- valid_error=144.2623 -- cost(Rec,KL)=(-128.4698,-17.3394) -- time=15.866
# epoch=25  -- train_error=144.7673 -- valid_error=143.8478 -- cost(Rec,KL)=(-127.5405,-17.2268) -- time=17.319
# epoch=26  -- train_error=144.1890 -- valid_error=144.0700 -- cost(Rec,KL)=(-127.0551,-17.1339) -- time=15.592
# epoch=27  -- train_error=143.9575 -- valid_error=142.9726 -- cost(Rec,KL)=(-126.8375,-17.1200) -- time=15.625
# epoch=28  -- train_error=144.1026 -- valid_error=144.2127 -- cost(Rec,KL)=(-126.9960,-17.1066) -- time=16.759
# epoch=29  -- train_error=144.0235 -- valid_error=142.7781 -- cost(Rec,KL)=(-126.8674,-17.1561) -- time=16.572
# epoch=30  -- train_error=143.2719 -- valid_error=142.5731 -- cost(Rec,KL)=(-126.2121,-17.0599) -- time=16.839
# epoch=31  -- train_error=142.9730 -- valid_error=142.2894 -- cost(Rec,KL)=(-125.9213,-17.0517) -- time=16.436
# epoch=32  -- train_error=143.1465 -- valid_error=143.2021 -- cost(Rec,KL)=(-126.0427,-17.1038) -- time=16.189
# epoch=33  -- train_error=143.2380 -- valid_error=142.3920 -- cost(Rec,KL)=(-126.1035,-17.1346) -- time=15.141
# epoch=34  -- train_error=142.4215 -- valid_error=142.0750 -- cost(Rec,KL)=(-125.3465,-17.0750) -- time=16.622
# epoch=35  -- train_error=142.0988 -- valid_error=141.9650 -- cost(Rec,KL)=(-125.0522,-17.0466) -- time=15.530
# epoch=36  -- train_error=142.1369 -- valid_error=141.1829 -- cost(Rec,KL)=(-125.0664,-17.0705) -- time=16.437
# epoch=37  -- train_error=142.0288 -- valid_error=141.8142 -- cost(Rec,KL)=(-124.9484,-17.0804) -- time=17.487
# epoch=38  -- train_error=141.9547 -- valid_error=141.2235 -- cost(Rec,KL)=(-124.8546,-17.1001) -- time=17.511
# epoch=39  -- train_error=141.5096 -- valid_error=141.0679 -- cost(Rec,KL)=(-124.4396,-17.0700) -- time=17.275
# epoch=40  -- train_error=141.2680 -- valid_error=140.7799 -- cost(Rec,KL)=(-124.1519,-17.1161) -- time=16.411
# epoch=41  -- train_error=141.1844 -- valid_error=140.3522 -- cost(Rec,KL)=(-124.0819,-17.1025) -- time=17.083
# epoch=42  -- train_error=141.2236 -- valid_error=140.8416 -- cost(Rec,KL)=(-124.0837,-17.1399) -- time=15.979
# epoch=43  -- train_error=140.8750 -- valid_error=140.0541 -- cost(Rec,KL)=(-123.7299,-17.1451) -- time=16.252
# epoch=44  -- train_error=140.4608 -- valid_error=139.7898 -- cost(Rec,KL)=(-123.3110,-17.1497) -- time=16.749
# epoch=45  -- train_error=140.4241 -- valid_error=141.1320 -- cost(Rec,KL)=(-123.2480,-17.1761) -- time=16.064
# epoch=46  -- train_error=140.5285 -- valid_error=140.0848 -- cost(Rec,KL)=(-123.3458,-17.1827) -- time=17.140
# epoch=47  -- train_error=140.0452 -- valid_error=139.2182 -- cost(Rec,KL)=(-122.8299,-17.2153) -- time=17.068
# epoch=48  -- train_error=139.5754 -- valid_error=138.9957 -- cost(Rec,KL)=(-122.3995,-17.1760) -- time=17.406
# epoch=49  -- train_error=139.4054 -- valid_error=139.5154 -- cost(Rec,KL)=(-122.1955,-17.2099) -- time=17.768
# epoch=50  -- train_error=139.4837 -- valid_error=139.4429 -- cost(Rec,KL)=(-122.2560,-17.2277) -- time=15.865
# epoch=51  -- train_error=139.2899 -- valid_error=138.8285 -- cost(Rec,KL)=(-122.0052,-17.2848) -- time=15.518
# epoch=52  -- train_error=138.7579 -- valid_error=138.1786 -- cost(Rec,KL)=(-121.4897,-17.2683) -- time=15.609
# epoch=53  -- train_error=139.0798 -- valid_error=138.0239 -- cost(Rec,KL)=(-121.7683,-17.3116) -- time=16.890
# epoch=54  -- train_error=139.3111 -- valid_error=137.9202 -- cost(Rec,KL)=(-121.8906,-17.4205) -- time=17.915
# epoch=55  -- train_error=138.5108 -- valid_error=137.9527 -- cost(Rec,KL)=(-121.1035,-17.4073) -- time=17.187
# epoch=56  -- train_error=137.8911 -- valid_error=137.4273 -- cost(Rec,KL)=(-120.5157,-17.3754) -- time=16.923
# epoch=57  -- train_error=137.3976 -- valid_error=137.0580 -- cost(Rec,KL)=(-120.0460,-17.3515) -- time=14.578
# epoch=58  -- train_error=137.1966 -- valid_error=136.9309 -- cost(Rec,KL)=(-119.8179,-17.3787) -- time=15.609
# epoch=59  -- train_error=137.1935 -- valid_error=137.1353 -- cost(Rec,KL)=(-119.7789,-17.4146) -- time=16.999
# epoch=60  -- train_error=137.4787 -- valid_error=137.8254 -- cost(Rec,KL)=(-119.9826,-17.4961) -- time=17.045
# epoch=61  -- train_error=137.6728 -- valid_error=136.5148 -- cost(Rec,KL)=(-120.0623,-17.6105) -- time=17.643
# epoch=62  -- train_error=137.1814 -- valid_error=136.0918 -- cost(Rec,KL)=(-119.5472,-17.6342) -- time=16.234
# epoch=63  -- train_error=136.4392 -- valid_error=135.8611 -- cost(Rec,KL)=(-118.8456,-17.5936) -- time=17.408
# epoch=64  -- train_error=135.9854 -- valid_error=135.4625 -- cost(Rec,KL)=(-118.3890,-17.5964) -- time=15.535
# epoch=65  -- train_error=135.6001 -- valid_error=135.2816 -- cost(Rec,KL)=(-118.0273,-17.5728) -- time=18.108
# epoch=66  -- train_error=135.7137 -- valid_error=135.6448 -- cost(Rec,KL)=(-118.0713,-17.6424) -- time=17.597
# epoch=67  -- train_error=135.7749 -- valid_error=135.1975 -- cost(Rec,KL)=(-118.0625,-17.7124) -- time=17.877
# epoch=68  -- train_error=135.1330 -- valid_error=134.3607 -- cost(Rec,KL)=(-117.3831,-17.7499) -- time=16.963
# epoch=69  -- train_error=135.0770 -- valid_error=134.8269 -- cost(Rec,KL)=(-117.2967,-17.7804) -- time=17.292
# epoch=70  -- train_error=135.1499 -- valid_error=134.2390 -- cost(Rec,KL)=(-117.3176,-17.8322) -- time=16.836
# epoch=71  -- train_error=134.4408 -- valid_error=133.8421 -- cost(Rec,KL)=(-116.6635,-17.7773) -- time=17.342
# epoch=72  -- train_error=133.9721 -- valid_error=133.8021 -- cost(Rec,KL)=(-116.1887,-17.7834) -- time=17.602
# epoch=73  -- train_error=133.7681 -- valid_error=133.3918 -- cost(Rec,KL)=(-115.9836,-17.7845) -- time=17.081
# epoch=74  -- train_error=133.4911 -- valid_error=133.3233 -- cost(Rec,KL)=(-115.6661,-17.8250) -- time=16.885
# epoch=75  -- train_error=133.2531 -- valid_error=133.2825 -- cost(Rec,KL)=(-115.4032,-17.8499) -- time=16.464
# epoch=76  -- train_error=133.1049 -- valid_error=132.7855 -- cost(Rec,KL)=(-115.2427,-17.8622) -- time=16.546
# epoch=77  -- train_error=132.9343 -- valid_error=132.6485 -- cost(Rec,KL)=(-115.0552,-17.8792) -- time=15.098
# epoch=78  -- train_error=132.8761 -- valid_error=132.6149 -- cost(Rec,KL)=(-114.9394,-17.9367) -- time=14.723
# epoch=79  -- train_error=132.7070 -- valid_error=132.6709 -- cost(Rec,KL)=(-114.7338,-17.9732) -- time=17.229
# epoch=80  -- train_error=132.3698 -- valid_error=132.2951 -- cost(Rec,KL)=(-114.3878,-17.9820) -- time=16.445
# epoch=81  -- train_error=131.9392 -- valid_error=131.5873 -- cost(Rec,KL)=(-113.9693,-17.9699) -- time=16.462
# epoch=82  -- train_error=131.5876 -- valid_error=131.3264 -- cost(Rec,KL)=(-113.6247,-17.9628) -- time=16.633
# epoch=83  -- train_error=131.4143 -- valid_error=131.1395 -- cost(Rec,KL)=(-113.4248,-17.9895) -- time=16.780
# epoch=84  -- train_error=131.2295 -- valid_error=131.2916 -- cost(Rec,KL)=(-113.2414,-17.9882) -- time=16.908
# epoch=85  -- train_error=131.0884 -- valid_error=130.7997 -- cost(Rec,KL)=(-113.0786,-18.0098) -- time=16.638
# epoch=86  -- train_error=131.0044 -- valid_error=130.6076 -- cost(Rec,KL)=(-112.9412,-18.0633) -- time=17.869
# epoch=87  -- train_error=130.9232 -- valid_error=130.3746 -- cost(Rec,KL)=(-112.8148,-18.1084) -- time=15.881
# epoch=88  -- train_error=130.7430 -- valid_error=130.0028 -- cost(Rec,KL)=(-112.6538,-18.0892) -- time=15.521
# epoch=89  -- train_error=130.2333 -- valid_error=129.5722 -- cost(Rec,KL)=(-112.1624,-18.0709) -- time=16.226
# epoch=90  -- train_error=129.8267 -- valid_error=129.4058 -- cost(Rec,KL)=(-111.7704,-18.0562) -- time=16.499
# epoch=91  -- train_error=129.6295 -- valid_error=129.2842 -- cost(Rec,KL)=(-111.5827,-18.0468) -- time=15.365
# epoch=92  -- train_error=129.4682 -- valid_error=129.4135 -- cost(Rec,KL)=(-111.4316,-18.0366) -- time=15.580
# epoch=93  -- train_error=129.3742 -- valid_error=129.0558 -- cost(Rec,KL)=(-111.3011,-18.0731) -- time=16.838
# epoch=94  -- train_error=129.1399 -- valid_error=129.1194 -- cost(Rec,KL)=(-111.0513,-18.0885) -- time=16.504
# epoch=95  -- train_error=128.7673 -- valid_error=128.7910 -- cost(Rec,KL)=(-110.6989,-18.0684) -- time=15.366
# epoch=96  -- train_error=128.7781 -- valid_error=129.0589 -- cost(Rec,KL)=(-110.6946,-18.0835) -- time=17.608
# epoch=97  -- train_error=128.8879 -- valid_error=128.8277 -- cost(Rec,KL)=(-110.7871,-18.1008) -- time=16.016
# epoch=98  -- train_error=128.6001 -- valid_error=128.2116 -- cost(Rec,KL)=(-110.4641,-18.1360) -- time=17.983
# epoch=99  -- train_error=128.4009 -- valid_error=128.1018 -- cost(Rec,KL)=(-110.2538,-18.1471) -- time=16.954
# epoch=100 -- train_error=127.9178 -- valid_error=127.8767 -- cost(Rec,KL)=(-109.8301,-18.0877) -- time=16.698
# epoch=101 -- train_error=127.7072 -- valid_error=127.2869 -- cost(Rec,KL)=(-109.6035,-18.1037) -- time=15.943
# epoch=102 -- train_error=127.4479 -- valid_error=127.6158 -- cost(Rec,KL)=(-109.3724,-18.0755) -- time=17.528
# epoch=103 -- train_error=127.3754 -- valid_error=127.1610 -- cost(Rec,KL)=(-109.2701,-18.1053) -- time=16.339
# epoch=104 -- train_error=127.1796 -- valid_error=127.2856 -- cost(Rec,KL)=(-109.0678,-18.1118) -- time=15.777
# epoch=105 -- train_error=127.1017 -- valid_error=126.8833 -- cost(Rec,KL)=(-108.9713,-18.1304) -- time=16.616
# epoch=106 -- train_error=126.8732 -- valid_error=126.7316 -- cost(Rec,KL)=(-108.7437,-18.1294) -- time=17.611
# epoch=107 -- train_error=126.6488 -- valid_error=126.9096 -- cost(Rec,KL)=(-108.5062,-18.1426) -- time=15.675
# epoch=108 -- train_error=127.1584 -- valid_error=126.4502 -- cost(Rec,KL)=(-108.9809,-18.1775) -- time=17.559
# epoch=109 -- train_error=126.6392 -- valid_error=126.3334 -- cost(Rec,KL)=(-108.4852,-18.1539) -- time=16.004
# epoch=110 -- train_error=125.9771 -- valid_error=125.9282 -- cost(Rec,KL)=(-107.8739,-18.1033) -- time=17.120
# epoch=111 -- train_error=125.8561 -- valid_error=125.6165 -- cost(Rec,KL)=(-107.7678,-18.0882) -- time=17.244
# epoch=112 -- train_error=125.7783 -- valid_error=125.5622 -- cost(Rec,KL)=(-107.6651,-18.1132) -- time=17.542
# epoch=113 -- train_error=125.6629 -- valid_error=125.7689 -- cost(Rec,KL)=(-107.5643,-18.0986) -- time=18.199
# epoch=114 -- train_error=125.9043 -- valid_error=126.1109 -- cost(Rec,KL)=(-107.7567,-18.1475) -- time=16.285
# epoch=115 -- train_error=125.7813 -- valid_error=125.2289 -- cost(Rec,KL)=(-107.6091,-18.1722) -- time=17.212
# epoch=116 -- train_error=125.4424 -- valid_error=125.1781 -- cost(Rec,KL)=(-107.2723,-18.1701) -- time=16.716
# epoch=117 -- train_error=125.1831 -- valid_error=125.1317 -- cost(Rec,KL)=(-107.0397,-18.1434) -- time=15.499
# epoch=118 -- train_error=125.0088 -- valid_error=124.9368 -- cost(Rec,KL)=(-106.8491,-18.1597) -- time=15.115
# epoch=119 -- train_error=124.9275 -- valid_error=124.8239 -- cost(Rec,KL)=(-106.7879,-18.1396) -- time=16.629
# epoch=120 -- train_error=124.7083 -- valid_error=124.6455 -- cost(Rec,KL)=(-106.5723,-18.1361) -- time=17.129
# epoch=121 -- train_error=124.4840 -- valid_error=124.5405 -- cost(Rec,KL)=(-106.3315,-18.1525) -- time=17.386
# epoch=122 -- train_error=124.2006 -- valid_error=124.2690 -- cost(Rec,KL)=(-106.0788,-18.1218) -- time=16.194
# epoch=123 -- train_error=124.3615 -- valid_error=124.0562 -- cost(Rec,KL)=(-106.2130,-18.1484) -- time=17.497
# epoch=124 -- train_error=124.4110 -- valid_error=124.0858 -- cost(Rec,KL)=(-106.2262,-18.1848) -- time=17.076
# epoch=125 -- train_error=124.1564 -- valid_error=124.0547 -- cost(Rec,KL)=(-106.0235,-18.1329) -- time=16.901
# epoch=126 -- train_error=123.7069 -- valid_error=123.5999 -- cost(Rec,KL)=(-105.5882,-18.1187) -- time=16.910
# epoch=127 -- train_error=123.3775 -- valid_error=123.3981 -- cost(Rec,KL)=(-105.3042,-18.0733) -- time=16.066
# epoch=128 -- train_error=123.3565 -- valid_error=123.3315 -- cost(Rec,KL)=(-105.2201,-18.1364) -- time=16.531
# epoch=129 -- train_error=123.5818 -- valid_error=123.9052 -- cost(Rec,KL)=(-105.4537,-18.1280) -- time=17.633
# epoch=130 -- train_error=123.5001 -- valid_error=123.6202 -- cost(Rec,KL)=(-105.3425,-18.1576) -- time=16.526
# epoch=131 -- train_error=123.1025 -- valid_error=122.9569 -- cost(Rec,KL)=(-104.9725,-18.1300) -- time=15.587
# epoch=132 -- train_error=122.7708 -- valid_error=123.0168 -- cost(Rec,KL)=(-104.6386,-18.1322) -- time=16.125
# epoch=133 -- train_error=122.8390 -- valid_error=122.5492 -- cost(Rec,KL)=(-104.7277,-18.1113) -- time=15.936
# epoch=134 -- train_error=122.9237 -- valid_error=122.9936 -- cost(Rec,KL)=(-104.7914,-18.1323) -- time=16.130
# epoch=135 -- train_error=122.6486 -- valid_error=122.4796 -- cost(Rec,KL)=(-104.5082,-18.1404) -- time=16.121
# epoch=136 -- train_error=122.4796 -- valid_error=122.6158 -- cost(Rec,KL)=(-104.3324,-18.1472) -- time=15.945
# epoch=137 -- train_error=122.3343 -- valid_error=122.5795 -- cost(Rec,KL)=(-104.2148,-18.1195) -- time=17.215
# epoch=138 -- train_error=122.2344 -- valid_error=122.4416 -- cost(Rec,KL)=(-104.0821,-18.1523) -- time=16.682
# epoch=139 -- train_error=122.0982 -- valid_error=121.9885 -- cost(Rec,KL)=(-103.9636,-18.1347) -- time=16.695
# epoch=140 -- train_error=121.9681 -- valid_error=122.2348 -- cost(Rec,KL)=(-103.8307,-18.1374) -- time=15.746
# epoch=141 -- train_error=122.0495 -- valid_error=121.8114 -- cost(Rec,KL)=(-103.8758,-18.1737) -- time=17.528
# epoch=142 -- train_error=121.8928 -- valid_error=122.0384 -- cost(Rec,KL)=(-103.7064,-18.1863) -- time=18.281
# epoch=143 -- train_error=121.7283 -- valid_error=121.8525 -- cost(Rec,KL)=(-103.5522,-18.1761) -- time=18.029
# epoch=144 -- train_error=121.4632 -- valid_error=121.4305 -- cost(Rec,KL)=(-103.3011,-18.1622) -- time=16.592
# epoch=145 -- train_error=121.2981 -- valid_error=121.4118 -- cost(Rec,KL)=(-103.1454,-18.1527) -- time=15.695
# epoch=146 -- train_error=121.2602 -- valid_error=121.4744 -- cost(Rec,KL)=(-103.0838,-18.1764) -- time=15.895
# epoch=147 -- train_error=121.3900 -- valid_error=121.5124 -- cost(Rec,KL)=(-103.2070,-18.1830) -- time=17.072
# epoch=148 -- train_error=121.1525 -- valid_error=121.2297 -- cost(Rec,KL)=(-103.0016,-18.1509) -- time=15.450
# epoch=149 -- train_error=121.0118 -- valid_error=121.1982 -- cost(Rec,KL)=(-102.8350,-18.1767) -- time=17.175
# epoch=150 -- train_error=120.8706 -- valid_error=120.8403 -- cost(Rec,KL)=(-102.6942,-18.1765) -- time=15.690
# epoch=151 -- train_error=120.8287 -- valid_error=120.9485 -- cost(Rec,KL)=(-102.6649,-18.1638) -- time=16.284
# epoch=152 -- train_error=120.6340 -- valid_error=120.7073 -- cost(Rec,KL)=(-102.4623,-18.1717) -- time=14.524
# epoch=153 -- train_error=120.3429 -- valid_error=120.5813 -- cost(Rec,KL)=(-102.2042,-18.1387) -- time=16.250
# epoch=154 -- train_error=120.2408 -- valid_error=120.3375 -- cost(Rec,KL)=(-102.0891,-18.1517) -- time=16.610
# epoch=155 -- train_error=120.2040 -- valid_error=120.3190 -- cost(Rec,KL)=(-102.0142,-18.1898) -- time=17.286
# epoch=156 -- train_error=120.1303 -- valid_error=120.0996 -- cost(Rec,KL)=(-101.9394,-18.1910) -- time=15.644
# epoch=157 -- train_error=120.1981 -- valid_error=120.4751 -- cost(Rec,KL)=(-102.0028,-18.1953) -- time=16.424
# epoch=158 -- train_error=120.2648 -- valid_error=120.0589 -- cost(Rec,KL)=(-102.0473,-18.2175) -- time=15.755
# epoch=159 -- train_error=119.9821 -- valid_error=120.0756 -- cost(Rec,KL)=(-101.7692,-18.2129) -- time=14.642
# epoch=160 -- train_error=119.8034 -- valid_error=120.2144 -- cost(Rec,KL)=(-101.6233,-18.1801) -- time=16.300
# epoch=161 -- train_error=119.6738 -- valid_error=119.7182 -- cost(Rec,KL)=(-101.4786,-18.1952) -- time=15.964
# epoch=162 -- train_error=119.4726 -- valid_error=119.7660 -- cost(Rec,KL)=(-101.3024,-18.1702) -- time=14.926
# epoch=163 -- train_error=119.3266 -- valid_error=119.6774 -- cost(Rec,KL)=(-101.1486,-18.1780) -- time=15.514
# epoch=164 -- train_error=119.4127 -- valid_error=119.8247 -- cost(Rec,KL)=(-101.2073,-18.2053) -- time=15.481
# epoch=165 -- train_error=119.4819 -- valid_error=119.7169 -- cost(Rec,KL)=(-101.2801,-18.2018) -- time=16.759
# epoch=166 -- train_error=119.4061 -- valid_error=119.5118 -- cost(Rec,KL)=(-101.2017,-18.2043) -- time=15.704
# epoch=167 -- train_error=119.0112 -- valid_error=119.1533 -- cost(Rec,KL)=(-100.8218,-18.1894) -- time=15.836
# epoch=168 -- train_error=118.8943 -- valid_error=119.0442 -- cost(Rec,KL)=(-100.7057,-18.1886) -- time=15.957
# epoch=169 -- train_error=118.7059 -- valid_error=118.8894 -- cost(Rec,KL)=(-100.5154,-18.1904) -- time=15.681
# epoch=170 -- train_error=118.5631 -- valid_error=118.8776 -- cost(Rec,KL)=(-100.3913,-18.1718) -- time=16.681
# epoch=171 -- train_error=118.7023 -- valid_error=118.9573 -- cost(Rec,KL)=(-100.4919,-18.2104) -- time=16.350
# epoch=172 -- train_error=118.7471 -- valid_error=119.4799 -- cost(Rec,KL)=(-100.5067,-18.2404) -- time=17.293
# epoch=173 -- train_error=118.6798 -- valid_error=119.0864 -- cost(Rec,KL)=(-100.4651,-18.2147) -- time=18.485
# epoch=174 -- train_error=118.5388 -- valid_error=118.7444 -- cost(Rec,KL)=(-100.3153,-18.2235) -- time=15.985
# epoch=175 -- train_error=118.4372 -- valid_error=118.8841 -- cost(Rec,KL)=(-100.2100,-18.2272) -- time=15.522
# epoch=176 -- train_error=118.2844 -- valid_error=118.6237 -- cost(Rec,KL)=(-100.0820,-18.2023) -- time=17.225
# epoch=177 -- train_error=118.0547 -- valid_error=118.1154 -- cost(Rec,KL)=(-99.8237,-18.2310) -- time=16.429
# epoch=178 -- train_error=118.0512 -- valid_error=118.3217 -- cost(Rec,KL)=(-99.8454,-18.2058) -- time=15.635
# epoch=179 -- train_error=117.9676 -- valid_error=118.2524 -- cost(Rec,KL)=(-99.7513,-18.2164) -- time=16.477
# epoch=180 -- train_error=117.7826 -- valid_error=117.9096 -- cost(Rec,KL)=(-99.5476,-18.2350) -- time=16.512
# epoch=181 -- train_error=117.8116 -- valid_error=118.0808 -- cost(Rec,KL)=(-99.5623,-18.2492) -- time=17.145
# epoch=182 -- train_error=117.9256 -- valid_error=117.8763 -- cost(Rec,KL)=(-99.6545,-18.2711) -- time=16.271
# epoch=183 -- train_error=117.5660 -- valid_error=117.7644 -- cost(Rec,KL)=(-99.3389,-18.2271) -- time=16.066
# epoch=184 -- train_error=117.4394 -- valid_error=117.7160 -- cost(Rec,KL)=(-99.2099,-18.2295) -- time=16.975
# epoch=185 -- train_error=117.5320 -- valid_error=117.9166 -- cost(Rec,KL)=(-99.2728,-18.2592) -- time=16.305
# epoch=186 -- train_error=117.5913 -- valid_error=117.5605 -- cost(Rec,KL)=(-99.3338,-18.2575) -- time=16.204
# epoch=187 -- train_error=117.4562 -- valid_error=117.7011 -- cost(Rec,KL)=(-99.1754,-18.2807) -- time=16.572
# epoch=188 -- train_error=117.2522 -- valid_error=117.6667 -- cost(Rec,KL)=(-99.0138,-18.2383) -- time=17.073
# epoch=189 -- train_error=117.2793 -- valid_error=117.7065 -- cost(Rec,KL)=(-99.0278,-18.2516) -- time=16.824
# epoch=190 -- train_error=117.1098 -- valid_error=117.8377 -- cost(Rec,KL)=(-98.8528,-18.2571) -- time=15.184
# epoch=191 -- train_error=116.9809 -- valid_error=117.3776 -- cost(Rec,KL)=(-98.7208,-18.2602) -- time=16.951
# epoch=192 -- train_error=116.7429 -- valid_error=117.1124 -- cost(Rec,KL)=(-98.4959,-18.2470) -- time=16.636
# epoch=193 -- train_error=116.6595 -- valid_error=117.1401 -- cost(Rec,KL)=(-98.4233,-18.2362) -- time=16.301
# epoch=194 -- train_error=116.7472 -- valid_error=116.9898 -- cost(Rec,KL)=(-98.4808,-18.2664) -- time=16.085
# epoch=195 -- train_error=116.8128 -- valid_error=116.9313 -- cost(Rec,KL)=(-98.5247,-18.2881) -- time=15.755
# epoch=196 -- train_error=116.5788 -- valid_error=117.1180 -- cost(Rec,KL)=(-98.3035,-18.2754) -- time=16.199
# epoch=197 -- train_error=116.6025 -- valid_error=116.8182 -- cost(Rec,KL)=(-98.3089,-18.2936) -- time=15.201
# epoch=198 -- train_error=116.5792 -- valid_error=117.0911 -- cost(Rec,KL)=(-98.3138,-18.2654) -- time=16.270
# epoch=199 -- train_error=116.4531 -- valid_error=116.4969 -- cost(Rec,KL)=(-98.1551,-18.2979) -- time=16.818
# epoch=200 -- train_error=116.3109 -- valid_error=116.4673 -- cost(Rec,KL)=(-98.0332,-18.2776) -- time=18.013
# epoch=201 -- train_error=116.1953 -- valid_error=116.7171 -- cost(Rec,KL)=(-97.8841,-18.3112) -- time=15.667
# epoch=202 -- train_error=115.9466 -- valid_error=116.2736 -- cost(Rec,KL)=(-97.6737,-18.2729) -- time=15.455
# epoch=203 -- train_error=115.9310 -- valid_error=116.5064 -- cost(Rec,KL)=(-97.6295,-18.3015) -- time=16.698
# epoch=204 -- train_error=116.1862 -- valid_error=116.8265 -- cost(Rec,KL)=(-97.8818,-18.3044) -- time=16.169
# epoch=205 -- train_error=116.1900 -- valid_error=116.3533 -- cost(Rec,KL)=(-97.8692,-18.3208) -- time=14.779
# epoch=206 -- train_error=115.9598 -- valid_error=116.1373 -- cost(Rec,KL)=(-97.6031,-18.3567) -- time=14.170
# epoch=207 -- train_error=115.8648 -- valid_error=116.3086 -- cost(Rec,KL)=(-97.5599,-18.3049) -- time=16.457
# epoch=208 -- train_error=116.0104 -- valid_error=116.5110 -- cost(Rec,KL)=(-97.6755,-18.3349) -- time=16.061
# epoch=209 -- train_error=115.8756 -- valid_error=116.1157 -- cost(Rec,KL)=(-97.5539,-18.3216) -- time=14.854
# epoch=210 -- train_error=115.4230 -- valid_error=115.7651 -- cost(Rec,KL)=(-97.1305,-18.2925) -- time=16.353
# epoch=211 -- train_error=115.2180 -- valid_error=115.6542 -- cost(Rec,KL)=(-96.9307,-18.2873) -- time=17.882
# epoch=212 -- train_error=115.1940 -- valid_error=115.7106 -- cost(Rec,KL)=(-96.9341,-18.2600) -- time=15.368
# epoch=213 -- train_error=115.3177 -- valid_error=115.6380 -- cost(Rec,KL)=(-97.0259,-18.2918) -- time=15.780
# epoch=214 -- train_error=115.4124 -- valid_error=116.0154 -- cost(Rec,KL)=(-97.1088,-18.3035) -- time=15.238
# epoch=215 -- train_error=115.3697 -- valid_error=116.1968 -- cost(Rec,KL)=(-97.0584,-18.3113) -- time=17.091
# epoch=216 -- train_error=115.1284 -- valid_error=115.5889 -- cost(Rec,KL)=(-96.8200,-18.3084) -- time=15.439
# epoch=217 -- train_error=114.9844 -- valid_error=115.4755 -- cost(Rec,KL)=(-96.6650,-18.3194) -- time=16.383
# epoch=218 -- train_error=114.9810 -- valid_error=115.4039 -- cost(Rec,KL)=(-96.6568,-18.3242) -- time=16.340
# epoch=219 -- train_error=115.0504 -- valid_error=115.3188 -- cost(Rec,KL)=(-96.7285,-18.3219) -- time=17.181
# epoch=220 -- train_error=114.8568 -- valid_error=115.1511 -- cost(Rec,KL)=(-96.5197,-18.3371) -- time=16.860
# epoch=221 -- train_error=114.6765 -- valid_error=115.0091 -- cost(Rec,KL)=(-96.3817,-18.2948) -- time=15.926
# epoch=222 -- train_error=114.6978 -- valid_error=115.1113 -- cost(Rec,KL)=(-96.3536,-18.3442) -- time=14.796
# epoch=223 -- train_error=115.0603 -- valid_error=116.1229 -- cost(Rec,KL)=(-96.7252,-18.3351) -- time=16.014
# epoch=224 -- train_error=115.0579 -- valid_error=115.2368 -- cost(Rec,KL)=(-96.7112,-18.3467) -- time=17.623
# epoch=225 -- train_error=114.5766 -- valid_error=114.9516 -- cost(Rec,KL)=(-96.2258,-18.3508) -- time=16.031
# epoch=226 -- train_error=114.2353 -- valid_error=114.7099 -- cost(Rec,KL)=(-95.9104,-18.3249) -- time=16.152
# epoch=227 -- train_error=114.2598 -- valid_error=115.2100 -- cost(Rec,KL)=(-95.9353,-18.3245) -- time=15.106
# epoch=228 -- train_error=114.6658 -- valid_error=115.0140 -- cost(Rec,KL)=(-96.3015,-18.3643) -- time=15.522
# epoch=229 -- train_error=114.8057 -- valid_error=115.2809 -- cost(Rec,KL)=(-96.3987,-18.4070) -- time=14.941
# epoch=230 -- train_error=114.3359 -- valid_error=114.7001 -- cost(Rec,KL)=(-95.9284,-18.4075) -- time=17.323
# epoch=231 -- train_error=114.1861 -- valid_error=114.9013 -- cost(Rec,KL)=(-95.8104,-18.3757) -- time=16.447
# epoch=232 -- train_error=114.4550 -- valid_error=114.8087 -- cost(Rec,KL)=(-96.0477,-18.4073) -- time=17.040
# epoch=233 -- train_error=114.3358 -- valid_error=114.8449 -- cost(Rec,KL)=(-95.9821,-18.3537) -- time=15.749
# epoch=234 -- train_error=114.0020 -- valid_error=114.4739 -- cost(Rec,KL)=(-95.6137,-18.3883) -- time=15.370
# epoch=235 -- train_error=113.8404 -- valid_error=114.5260 -- cost(Rec,KL)=(-95.4952,-18.3452) -- time=16.693
# epoch=236 -- train_error=113.9194 -- valid_error=114.6955 -- cost(Rec,KL)=(-95.5482,-18.3712) -- time=15.803
# epoch=237 -- train_error=114.0389 -- valid_error=114.7443 -- cost(Rec,KL)=(-95.6516,-18.3873) -- time=16.178
# epoch=238 -- train_error=113.8884 -- valid_error=114.4191 -- cost(Rec,KL)=(-95.5106,-18.3778) -- time=16.341
# epoch=239 -- train_error=113.6576 -- valid_error=114.2593 -- cost(Rec,KL)=(-95.2991,-18.3585) -- time=16.998
# epoch=240 -- train_error=113.7240 -- valid_error=114.6136 -- cost(Rec,KL)=(-95.3594,-18.3646) -- time=16.870
# epoch=241 -- train_error=113.8586 -- valid_error=114.3374 -- cost(Rec,KL)=(-95.4575,-18.4011) -- time=17.378
# epoch=242 -- train_error=113.6342 -- valid_error=114.2080 -- cost(Rec,KL)=(-95.2629,-18.3713) -- time=17.345
# epoch=243 -- train_error=113.4700 -- valid_error=114.0584 -- cost(Rec,KL)=(-95.0872,-18.3828) -- time=16.223
# epoch=244 -- train_error=113.4063 -- valid_error=114.0542 -- cost(Rec,KL)=(-95.0031,-18.4031) -- time=17.548
# epoch=245 -- train_error=113.5083 -- valid_error=114.0720 -- cost(Rec,KL)=(-95.1396,-18.3687) -- time=16.694
# epoch=246 -- train_error=113.5842 -- valid_error=114.2541 -- cost(Rec,KL)=(-95.1884,-18.3957) -- time=15.952
# epoch=247 -- train_error=113.4762 -- valid_error=113.6485 -- cost(Rec,KL)=(-95.0704,-18.4058) -- time=15.880
# epoch=248 -- train_error=113.2352 -- valid_error=113.8381 -- cost(Rec,KL)=(-94.8118,-18.4234) -- time=16.495
# epoch=249 -- train_error=113.2799 -- valid_error=114.1621 -- cost(Rec,KL)=(-94.8798,-18.4001) -- time=16.093
# epoch=250 -- train_error=113.3525 -- valid_error=114.1742 -- cost(Rec,KL)=(-94.9425,-18.4100) -- time=15.773
# epoch=251 -- train_error=113.2643 -- valid_error=113.8228 -- cost(Rec,KL)=(-94.8414,-18.4230) -- time=15.111
# epoch=252 -- train_error=113.0673 -- valid_error=113.6592 -- cost(Rec,KL)=(-94.6603,-18.4070) -- time=15.742
# epoch=253 -- train_error=112.9657 -- valid_error=113.5051 -- cost(Rec,KL)=(-94.5708,-18.3950) -- time=15.931
# epoch=254 -- train_error=112.8296 -- valid_error=113.4661 -- cost(Rec,KL)=(-94.4519,-18.3777) -- time=15.925
# epoch=255 -- train_error=112.9166 -- valid_error=113.6624 -- cost(Rec,KL)=(-94.5112,-18.4054) -- time=17.561
# epoch=256 -- train_error=112.9852 -- valid_error=113.5246 -- cost(Rec,KL)=(-94.5384,-18.4469) -- time=15.648
# epoch=257 -- train_error=112.8486 -- valid_error=113.6343 -- cost(Rec,KL)=(-94.4147,-18.4339) -- time=15.810
# epoch=258 -- train_error=112.7649 -- valid_error=113.4335 -- cost(Rec,KL)=(-94.3531,-18.4119) -- time=15.899
# epoch=259 -- train_error=112.8031 -- valid_error=113.7055 -- cost(Rec,KL)=(-94.3784,-18.4247) -- time=15.637
# epoch=260 -- train_error=113.0261 -- valid_error=113.8876 -- cost(Rec,KL)=(-94.5706,-18.4555) -- time=16.140
# epoch=261 -- train_error=112.8698 -- valid_error=113.5107 -- cost(Rec,KL)=(-94.4271,-18.4427) -- time=17.316
# epoch=262 -- train_error=112.4300 -- valid_error=113.2648 -- cost(Rec,KL)=(-94.0288,-18.4012) -- time=16.300
# epoch=263 -- train_error=112.4276 -- valid_error=113.5725 -- cost(Rec,KL)=(-93.9924,-18.4352) -- time=15.785
# epoch=264 -- train_error=112.7553 -- valid_error=113.6345 -- cost(Rec,KL)=(-94.3068,-18.4485) -- time=15.065
# epoch=265 -- train_error=112.7090 -- valid_error=113.0183 -- cost(Rec,KL)=(-94.2554,-18.4536) -- time=16.541
# epoch=266 -- train_error=112.2591 -- valid_error=112.8963 -- cost(Rec,KL)=(-93.8261,-18.4330) -- time=16.359
# epoch=267 -- train_error=112.0884 -- valid_error=112.9977 -- cost(Rec,KL)=(-93.6597,-18.4287) -- time=16.834
# epoch=268 -- train_error=112.2127 -- valid_error=113.0778 -- cost(Rec,KL)=(-93.7831,-18.4295) -- time=16.186
# epoch=269 -- train_error=112.5327 -- valid_error=113.3161 -- cost(Rec,KL)=(-94.0834,-18.4493) -- time=15.069
# epoch=270 -- train_error=112.5005 -- valid_error=112.7566 -- cost(Rec,KL)=(-94.0226,-18.4779) -- time=16.875
# epoch=271 -- train_error=112.1871 -- valid_error=113.1917 -- cost(Rec,KL)=(-93.7505,-18.4366) -- time=14.161
# epoch=272 -- train_error=112.2094 -- valid_error=113.4579 -- cost(Rec,KL)=(-93.7577,-18.4518) -- time=16.234
# epoch=273 -- train_error=112.2767 -- valid_error=113.3573 -- cost(Rec,KL)=(-93.7761,-18.5007) -- time=17.129
# epoch=274 -- train_error=112.0057 -- valid_error=112.6016 -- cost(Rec,KL)=(-93.5629,-18.4428) -- time=16.127
# epoch=275 -- train_error=111.8768 -- valid_error=112.5769 -- cost(Rec,KL)=(-93.4074,-18.4695) -- time=16.762
# epoch=276 -- train_error=111.9494 -- valid_error=112.9185 -- cost(Rec,KL)=(-93.4996,-18.4498) -- time=14.962
# epoch=277 -- train_error=111.9645 -- valid_error=112.8175 -- cost(Rec,KL)=(-93.5140,-18.4505) -- time=15.765
# epoch=278 -- train_error=112.0957 -- valid_error=112.8818 -- cost(Rec,KL)=(-93.5893,-18.5065) -- time=16.257
# epoch=279 -- train_error=111.9821 -- valid_error=112.7151 -- cost(Rec,KL)=(-93.5065,-18.4756) -- time=17.122
# epoch=280 -- train_error=111.9864 -- valid_error=112.8515 -- cost(Rec,KL)=(-93.5021,-18.4843) -- time=16.435
# epoch=281 -- train_error=111.9194 -- valid_error=112.8559 -- cost(Rec,KL)=(-93.4460,-18.4733) -- time=15.837
# epoch=282 -- train_error=111.6113 -- valid_error=112.5458 -- cost(Rec,KL)=(-93.1413,-18.4699) -- time=14.090
# epoch=283 -- train_error=111.4662 -- valid_error=112.4735 -- cost(Rec,KL)=(-93.0047,-18.4616) -- time=16.088
# epoch=284 -- train_error=111.5363 -- valid_error=112.3965 -- cost(Rec,KL)=(-93.0392,-18.4971) -- time=15.883
# epoch=285 -- train_error=111.4708 -- valid_error=112.4596 -- cost(Rec,KL)=(-92.9977,-18.4731) -- time=16.435
# epoch=286 -- train_error=111.3863 -- valid_error=112.4151 -- cost(Rec,KL)=(-92.8873,-18.4990) -- time=16.565
# epoch=287 -- train_error=111.6642 -- valid_error=112.9119 -- cost(Rec,KL)=(-93.1905,-18.4736) -- time=15.976
# epoch=288 -- train_error=111.9242 -- valid_error=112.7109 -- cost(Rec,KL)=(-93.3870,-18.5372) -- time=14.952
# epoch=289 -- train_error=111.6395 -- valid_error=112.2251 -- cost(Rec,KL)=(-93.1405,-18.4989) -- time=15.798
# epoch=290 -- train_error=111.4304 -- valid_error=112.4754 -- cost(Rec,KL)=(-92.9253,-18.5051) -- time=16.296
# epoch=291 -- train_error=111.1976 -- valid_error=112.0865 -- cost(Rec,KL)=(-92.6879,-18.5097) -- time=15.839
# epoch=292 -- train_error=111.2452 -- valid_error=112.1278 -- cost(Rec,KL)=(-92.7259,-18.5193) -- time=15.847
# epoch=293 -- train_error=111.4063 -- valid_error=112.4977 -- cost(Rec,KL)=(-92.8866,-18.5196) -- time=16.126
# epoch=294 -- train_error=111.3183 -- valid_error=111.9586 -- cost(Rec,KL)=(-92.8354,-18.4829) -- time=17.402
# epoch=295 -- train_error=111.0844 -- valid_error=111.9878 -- cost(Rec,KL)=(-92.5644,-18.5200) -- time=14.988
# epoch=296 -- train_error=111.0247 -- valid_error=112.1954 -- cost(Rec,KL)=(-92.5087,-18.5160) -- time=16.110
# epoch=297 -- train_error=111.0670 -- valid_error=111.9116 -- cost(Rec,KL)=(-92.5644,-18.5026) -- time=17.212
# epoch=298 -- train_error=111.1864 -- valid_error=112.0209 -- cost(Rec,KL)=(-92.6656,-18.5207) -- time=16.093
# epoch=299 -- train_error=111.3681 -- valid_error=112.0587 -- cost(Rec,KL)=(-92.8261,-18.5421) -- time=15.316
# epoch=300 -- train_error=111.2141 -- valid_error=111.6735 -- cost(Rec,KL)=(-92.6658,-18.5482) -- time=15.339
# epoch=301 -- train_error=110.8152 -- valid_error=111.7979 -- cost(Rec,KL)=(-92.2965,-18.5186) -- time=15.458
# epoch=302 -- train_error=110.7566 -- valid_error=111.9597 -- cost(Rec,KL)=(-92.2539,-18.5027) -- time=17.021
# epoch=303 -- train_error=111.0595 -- valid_error=111.8587 -- cost(Rec,KL)=(-92.5145,-18.5450) -- time=17.205
# epoch=304 -- train_error=111.2356 -- valid_error=112.3915 -- cost(Rec,KL)=(-92.6866,-18.5489) -- time=18.741
# epoch=305 -- train_error=110.9282 -- valid_error=111.5624 -- cost(Rec,KL)=(-92.4032,-18.5250) -- time=16.123
# epoch=306 -- train_error=110.6651 -- valid_error=111.6061 -- cost(Rec,KL)=(-92.1363,-18.5288) -- time=17.157
# epoch=307 -- train_error=110.5998 -- valid_error=111.6587 -- cost(Rec,KL)=(-92.0605,-18.5394) -- time=16.081
# epoch=308 -- train_error=110.6559 -- valid_error=111.4060 -- cost(Rec,KL)=(-92.1135,-18.5423) -- time=16.612
# epoch=309 -- train_error=110.6115 -- valid_error=111.8711 -- cost(Rec,KL)=(-92.0741,-18.5374) -- time=17.435
# epoch=310 -- train_error=110.5909 -- valid_error=111.7389 -- cost(Rec,KL)=(-92.0695,-18.5214) -- time=15.961
# epoch=311 -- train_error=110.7102 -- valid_error=111.8131 -- cost(Rec,KL)=(-92.1429,-18.5673) -- time=15.595
# epoch=312 -- train_error=110.7373 -- valid_error=112.2619 -- cost(Rec,KL)=(-92.1899,-18.5474) -- time=16.982
# epoch=313 -- train_error=110.8603 -- valid_error=111.5626 -- cost(Rec,KL)=(-92.3044,-18.5559) -- time=16.484
# epoch=314 -- train_error=110.8040 -- valid_error=112.0613 -- cost(Rec,KL)=(-92.2300,-18.5740) -- time=17.045
# epoch=315 -- train_error=110.4078 -- valid_error=111.3044 -- cost(Rec,KL)=(-91.8614,-18.5463) -- time=15.751
# epoch=316 -- train_error=110.2248 -- valid_error=111.2364 -- cost(Rec,KL)=(-91.6740,-18.5508) -- time=15.091
# epoch=317 -- train_error=110.1906 -- valid_error=111.3831 -- cost(Rec,KL)=(-91.6361,-18.5545) -- time=16.089
# epoch=318 -- train_error=110.2618 -- valid_error=111.3951 -- cost(Rec,KL)=(-91.7081,-18.5536) -- time=14.975
# epoch=319 -- train_error=110.3922 -- valid_error=111.5468 -- cost(Rec,KL)=(-91.8130,-18.5792) -- time=15.612
# epoch=320 -- train_error=110.6607 -- valid_error=112.0729 -- cost(Rec,KL)=(-92.0880,-18.5727) -- time=17.123
# epoch=321 -- train_error=110.4214 -- valid_error=111.4478 -- cost(Rec,KL)=(-91.8221,-18.5993) -- time=16.593
# epoch=322 -- train_error=110.1727 -- valid_error=111.3000 -- cost(Rec,KL)=(-91.6100,-18.5627) -- time=16.171
# epoch=323 -- train_error=110.0512 -- valid_error=111.1062 -- cost(Rec,KL)=(-91.4974,-18.5537) -- time=15.643
# epoch=324 -- train_error=110.2917 -- valid_error=111.4226 -- cost(Rec,KL)=(-91.7195,-18.5722) -- time=17.060
# epoch=325 -- train_error=110.1998 -- valid_error=111.0879 -- cost(Rec,KL)=(-91.6139,-18.5859) -- time=16.570
# epoch=326 -- train_error=110.0498 -- valid_error=111.1717 -- cost(Rec,KL)=(-91.4787,-18.5710) -- time=16.411
# epoch=327 -- train_error=110.1745 -- valid_error=111.1095 -- cost(Rec,KL)=(-91.5948,-18.5797) -- time=16.161
# epoch=328 -- train_error=110.2188 -- valid_error=111.0922 -- cost(Rec,KL)=(-91.6289,-18.5899) -- time=16.293
# epoch=329 -- train_error=110.0655 -- valid_error=111.3021 -- cost(Rec,KL)=(-91.4767,-18.5888) -- time=14.788
# epoch=330 -- train_error=109.8657 -- valid_error=111.1877 -- cost(Rec,KL)=(-91.3016,-18.5641) -- time=15.495
# epoch=331 -- train_error=110.0303 -- valid_error=111.3097 -- cost(Rec,KL)=(-91.4316,-18.5987) -- time=16.911
# epoch=332 -- train_error=110.0755 -- valid_error=111.3699 -- cost(Rec,KL)=(-91.4875,-18.5880) -- time=16.443
# epoch=333 -- train_error=109.9211 -- valid_error=110.8081 -- cost(Rec,KL)=(-91.3205,-18.6006) -- time=16.330
# epoch=334 -- train_error=109.7681 -- valid_error=110.7045 -- cost(Rec,KL)=(-91.1688,-18.5993) -- time=15.569
# epoch=335 -- train_error=109.7356 -- valid_error=111.2566 -- cost(Rec,KL)=(-91.1315,-18.6041) -- time=16.696
# epoch=336 -- train_error=109.7574 -- valid_error=110.8943 -- cost(Rec,KL)=(-91.1604,-18.5970) -- time=15.916
# epoch=337 -- train_error=109.8994 -- valid_error=110.7865 -- cost(Rec,KL)=(-91.2997,-18.5996) -- time=16.341
# epoch=338 -- train_error=109.8208 -- valid_error=110.8413 -- cost(Rec,KL)=(-91.2099,-18.6109) -- time=16.327
# epoch=339 -- train_error=109.7455 -- valid_error=110.8175 -- cost(Rec,KL)=(-91.1462,-18.5993) -- time=15.515
# epoch=340 -- train_error=109.7583 -- valid_error=111.1077 -- cost(Rec,KL)=(-91.1330,-18.6253) -- time=15.467
# epoch=341 -- train_error=109.6341 -- valid_error=110.5920 -- cost(Rec,KL)=(-91.0195,-18.6146) -- time=16.242
# epoch=342 -- train_error=109.5120 -- valid_error=110.4648 -- cost(Rec,KL)=(-90.9286,-18.5834) -- time=15.426
# epoch=343 -- train_error=109.4241 -- valid_error=110.8286 -- cost(Rec,KL)=(-90.8086,-18.6155) -- time=15.571
# epoch=344 -- train_error=109.7885 -- valid_error=111.7447 -- cost(Rec,KL)=(-91.1736,-18.6149) -- time=16.076
# epoch=345 -- train_error=110.0024 -- valid_error=110.9366 -- cost(Rec,KL)=(-91.3755,-18.6270) -- time=15.752
# epoch=346 -- train_error=109.6626 -- valid_error=110.6219 -- cost(Rec,KL)=(-91.0265,-18.6361) -- time=17.208
# epoch=347 -- train_error=109.4135 -- valid_error=110.7769 -- cost(Rec,KL)=(-90.7848,-18.6287) -- time=16.732
# epoch=348 -- train_error=109.3240 -- valid_error=110.4069 -- cost(Rec,KL)=(-90.6916,-18.6324) -- time=16.186
# epoch=349 -- train_error=109.2685 -- valid_error=110.7316 -- cost(Rec,KL)=(-90.6340,-18.6345) -- time=16.258
# epoch=350 -- train_error=109.3678 -- valid_error=110.7871 -- cost(Rec,KL)=(-90.7518,-18.6160) -- time=14.303
# epoch=351 -- train_error=109.3351 -- valid_error=110.6061 -- cost(Rec,KL)=(-90.6981,-18.6371) -- time=16.147
# epoch=352 -- train_error=109.2169 -- valid_error=110.3834 -- cost(Rec,KL)=(-90.5857,-18.6312) -- time=16.154
# epoch=353 -- train_error=109.1460 -- valid_error=110.7390 -- cost(Rec,KL)=(-90.5322,-18.6138) -- time=17.954
# epoch=354 -- train_error=109.3301 -- valid_error=110.4626 -- cost(Rec,KL)=(-90.7063,-18.6238) -- time=16.938
# epoch=355 -- train_error=109.4455 -- valid_error=110.6915 -- cost(Rec,KL)=(-90.7876,-18.6579) -- time=15.458
# epoch=356 -- train_error=109.3250 -- valid_error=110.3318 -- cost(Rec,KL)=(-90.6657,-18.6593) -- time=17.557
# epoch=357 -- train_error=109.2029 -- valid_error=110.7638 -- cost(Rec,KL)=(-90.5679,-18.6350) -- time=15.078
# epoch=358 -- train_error=109.3821 -- valid_error=111.3661 -- cost(Rec,KL)=(-90.7150,-18.6671) -- time=17.509
# epoch=359 -- train_error=109.5280 -- valid_error=110.6336 -- cost(Rec,KL)=(-90.8512,-18.6768) -- time=16.849
# epoch=360 -- train_error=109.2258 -- valid_error=110.5581 -- cost(Rec,KL)=(-90.5741,-18.6517) -- time=16.608
# epoch=361 -- train_error=108.9819 -- valid_error=110.1900 -- cost(Rec,KL)=(-90.3551,-18.6268) -- time=16.666
# epoch=362 -- train_error=109.0521 -- valid_error=110.6553 -- cost(Rec,KL)=(-90.3977,-18.6544) -- time=16.426
# epoch=363 -- train_error=109.2081 -- valid_error=110.2237 -- cost(Rec,KL)=(-90.5417,-18.6664) -- time=16.741
# epoch=364 -- train_error=108.9004 -- valid_error=110.2211 -- cost(Rec,KL)=(-90.2469,-18.6535) -- time=17.526
# epoch=365 -- train_error=108.7508 -- valid_error=110.0981 -- cost(Rec,KL)=(-90.1057,-18.6451) -- time=18.698
# epoch=366 -- train_error=108.8054 -- valid_error=110.1364 -- cost(Rec,KL)=(-90.1735,-18.6319) -- time=16.172
# epoch=367 -- train_error=108.9171 -- valid_error=110.1859 -- cost(Rec,KL)=(-90.2430,-18.6742) -- time=17.508
# epoch=368 -- train_error=108.9543 -- valid_error=110.3040 -- cost(Rec,KL)=(-90.2972,-18.6571) -- time=15.374
# epoch=369 -- train_error=108.9509 -- valid_error=110.2193 -- cost(Rec,KL)=(-90.2995,-18.6514) -- time=14.742
# epoch=370 -- train_error=108.8504 -- valid_error=110.0504 -- cost(Rec,KL)=(-90.1754,-18.6751) -- time=17.096
# epoch=371 -- train_error=108.7620 -- valid_error=110.3363 -- cost(Rec,KL)=(-90.1105,-18.6515) -- time=16.816
# epoch=372 -- train_error=108.7461 -- valid_error=109.9186 -- cost(Rec,KL)=(-90.0923,-18.6537) -- time=17.422
# epoch=373 -- train_error=108.7851 -- valid_error=109.9662 -- cost(Rec,KL)=(-90.1144,-18.6707) -- time=15.980
# epoch=374 -- train_error=108.8453 -- valid_error=110.0630 -- cost(Rec,KL)=(-90.1590,-18.6863) -- time=16.054
# epoch=375 -- train_error=108.8658 -- valid_error=110.4537 -- cost(Rec,KL)=(-90.1892,-18.6766) -- time=17.259
# epoch=376 -- train_error=108.8631 -- valid_error=110.1168 -- cost(Rec,KL)=(-90.1584,-18.7048) -- time=15.815
# epoch=377 -- train_error=108.7513 -- valid_error=110.1485 -- cost(Rec,KL)=(-90.0952,-18.6561) -- time=15.424
# epoch=378 -- train_error=108.7457 -- valid_error=110.2655 -- cost(Rec,KL)=(-90.0571,-18.6886) -- time=16.508
# epoch=379 -- train_error=108.8122 -- valid_error=110.2718 -- cost(Rec,KL)=(-90.1215,-18.6907) -- time=16.624
# epoch=380 -- train_error=108.5591 -- valid_error=109.9405 -- cost(Rec,KL)=(-89.8897,-18.6694) -- time=15.459
# epoch=381 -- train_error=108.4363 -- valid_error=109.7700 -- cost(Rec,KL)=(-89.7549,-18.6814) -- time=16.357
# epoch=382 -- train_error=108.4490 -- valid_error=109.6990 -- cost(Rec,KL)=(-89.7466,-18.7024) -- time=17.153
# epoch=383 -- train_error=108.5421 -- valid_error=109.9184 -- cost(Rec,KL)=(-89.8585,-18.6836) -- time=15.968
# epoch=384 -- train_error=108.3471 -- valid_error=109.6352 -- cost(Rec,KL)=(-89.6686,-18.6785) -- time=16.604
# epoch=385 -- train_error=108.2861 -- valid_error=109.7079 -- cost(Rec,KL)=(-89.5968,-18.6894) -- time=15.116
# epoch=386 -- train_error=108.5295 -- valid_error=110.1067 -- cost(Rec,KL)=(-89.8294,-18.7001) -- time=17.336
# epoch=387 -- train_error=108.6383 -- valid_error=109.9911 -- cost(Rec,KL)=(-89.9277,-18.7106) -- time=16.672
# epoch=388 -- train_error=108.5754 -- valid_error=109.9570 -- cost(Rec,KL)=(-89.8523,-18.7231) -- time=15.729
# epoch=389 -- train_error=108.3860 -- valid_error=109.6436 -- cost(Rec,KL)=(-89.6665,-18.7195) -- time=15.911
# epoch=390 -- train_error=108.3999 -- valid_error=109.9383 -- cost(Rec,KL)=(-89.6861,-18.7138) -- time=15.974
# epoch=391 -- train_error=108.4178 -- valid_error=109.8923 -- cost(Rec,KL)=(-89.7156,-18.7022) -- time=17.505
# epoch=392 -- train_error=108.3199 -- valid_error=109.8790 -- cost(Rec,KL)=(-89.6072,-18.7127) -- time=15.028
# epoch=393 -- train_error=108.2250 -- valid_error=109.5971 -- cost(Rec,KL)=(-89.5171,-18.7078) -- time=16.039
# epoch=394 -- train_error=108.2115 -- valid_error=109.4762 -- cost(Rec,KL)=(-89.5263,-18.6852) -- time=16.256
# epoch=395 -- train_error=108.3392 -- valid_error=110.0041 -- cost(Rec,KL)=(-89.6111,-18.7281) -- time=16.811
# epoch=396 -- train_error=108.4107 -- valid_error=109.8179 -- cost(Rec,KL)=(-89.6972,-18.7134) -- time=14.514
# epoch=397 -- train_error=108.1749 -- valid_error=109.7610 -- cost(Rec,KL)=(-89.4551,-18.7198) -- time=15.872
# epoch=398 -- train_error=108.0990 -- valid_error=109.7023 -- cost(Rec,KL)=(-89.3794,-18.7196) -- time=15.816
# epoch=399 -- train_error=107.9505 -- valid_error=109.6762 -- cost(Rec,KL)=(-89.2251,-18.7254) -- time=16.557
# epoch=400 -- train_error=107.9644 -- valid_error=109.5323 -- cost(Rec,KL)=(-89.2758,-18.6886) -- time=16.210
# epoch=401 -- train_error=108.0513 -- valid_error=109.7211 -- cost(Rec,KL)=(-89.3150,-18.7363) -- time=15.793
# epoch=402 -- train_error=108.1405 -- valid_error=109.6882 -- cost(Rec,KL)=(-89.4187,-18.7219) -- time=16.691
# epoch=403 -- train_error=108.2514 -- valid_error=110.2612 -- cost(Rec,KL)=(-89.5255,-18.7258) -- time=15.463
# epoch=404 -- train_error=108.2135 -- valid_error=109.6470 -- cost(Rec,KL)=(-89.4747,-18.7387) -- time=16.722
# epoch=405 -- train_error=108.0340 -- valid_error=109.6281 -- cost(Rec,KL)=(-89.3144,-18.7196) -- time=15.464
# epoch=406 -- train_error=107.9542 -- valid_error=109.4322 -- cost(Rec,KL)=(-89.2326,-18.7216) -- time=16.164
# epoch=407 -- train_error=108.1629 -- valid_error=109.3896 -- cost(Rec,KL)=(-89.4136,-18.7493) -- time=15.182
# epoch=408 -- train_error=108.1830 -- valid_error=109.6628 -- cost(Rec,KL)=(-89.4624,-18.7206) -- time=15.689
# epoch=409 -- train_error=108.0228 -- valid_error=109.2927 -- cost(Rec,KL)=(-89.2773,-18.7455) -- time=15.600
# epoch=410 -- train_error=107.7976 -- valid_error=109.6896 -- cost(Rec,KL)=(-89.0727,-18.7249) -- time=16.566
# epoch=411 -- train_error=107.7535 -- valid_error=109.3941 -- cost(Rec,KL)=(-89.0236,-18.7299) -- time=16.933
# epoch=412 -- train_error=107.7223 -- valid_error=109.1728 -- cost(Rec,KL)=(-89.0074,-18.7148) -- time=16.457
# epoch=413 -- train_error=107.7898 -- valid_error=109.3814 -- cost(Rec,KL)=(-89.0453,-18.7445) -- time=17.131
# epoch=414 -- train_error=107.7655 -- valid_error=109.2554 -- cost(Rec,KL)=(-89.0468,-18.7187) -- time=15.846
# epoch=415 -- train_error=107.9192 -- valid_error=109.6956 -- cost(Rec,KL)=(-89.1499,-18.7693) -- time=15.946
# epoch=416 -- train_error=107.8516 -- valid_error=109.3097 -- cost(Rec,KL)=(-89.1100,-18.7417) -- time=16.628
# epoch=417 -- train_error=107.6420 -- valid_error=109.2136 -- cost(Rec,KL)=(-88.9100,-18.7319) -- time=15.597
# epoch=418 -- train_error=107.6008 -- valid_error=109.3511 -- cost(Rec,KL)=(-88.8446,-18.7562) -- time=14.773
# epoch=419 -- train_error=107.7108 -- valid_error=109.2418 -- cost(Rec,KL)=(-88.9614,-18.7494) -- time=16.719
# epoch=420 -- train_error=107.5925 -- valid_error=109.0853 -- cost(Rec,KL)=(-88.8326,-18.7599) -- time=15.664
# epoch=421 -- train_error=107.6199 -- valid_error=109.0198 -- cost(Rec,KL)=(-88.8733,-18.7466) -- time=17.041
# epoch=422 -- train_error=107.7744 -- valid_error=109.7472 -- cost(Rec,KL)=(-89.0016,-18.7728) -- time=17.623
# epoch=423 -- train_error=107.7691 -- valid_error=109.5149 -- cost(Rec,KL)=(-89.0287,-18.7404) -- time=16.399
# epoch=424 -- train_error=107.7182 -- valid_error=109.3773 -- cost(Rec,KL)=(-88.9568,-18.7615) -- time=15.951
# epoch=425 -- train_error=107.6984 -- valid_error=109.4557 -- cost(Rec,KL)=(-88.9296,-18.7688) -- time=15.083
# epoch=426 -- train_error=107.6773 -- valid_error=109.1618 -- cost(Rec,KL)=(-88.9079,-18.7694) -- time=14.545
# epoch=427 -- train_error=107.6042 -- valid_error=108.9556 -- cost(Rec,KL)=(-88.8290,-18.7752) -- time=16.030
# epoch=428 -- train_error=107.5040 -- valid_error=109.0169 -- cost(Rec,KL)=(-88.7466,-18.7573) -- time=18.609
# epoch=429 -- train_error=107.5014 -- valid_error=109.1177 -- cost(Rec,KL)=(-88.7738,-18.7276) -- time=16.493
# epoch=430 -- train_error=107.4935 -- valid_error=109.3580 -- cost(Rec,KL)=(-88.7246,-18.7689) -- time=17.497
# epoch=431 -- train_error=107.2900 -- valid_error=109.0175 -- cost(Rec,KL)=(-88.5396,-18.7504) -- time=15.415
# epoch=432 -- train_error=107.2013 -- valid_error=108.9411 -- cost(Rec,KL)=(-88.4387,-18.7626) -- time=16.147
# epoch=433 -- train_error=107.3498 -- valid_error=108.6641 -- cost(Rec,KL)=(-88.5747,-18.7751) -- time=15.490
# epoch=434 -- train_error=107.3761 -- valid_error=109.1393 -- cost(Rec,KL)=(-88.6023,-18.7738) -- time=16.141
# epoch=435 -- train_error=107.3445 -- valid_error=109.0291 -- cost(Rec,KL)=(-88.5780,-18.7665) -- time=17.325
# epoch=436 -- train_error=107.4188 -- valid_error=108.9291 -- cost(Rec,KL)=(-88.6438,-18.7750) -- time=17.270
# epoch=437 -- train_error=107.4879 -- valid_error=108.9774 -- cost(Rec,KL)=(-88.6964,-18.7915) -- time=15.206
# epoch=438 -- train_error=107.3014 -- valid_error=108.8708 -- cost(Rec,KL)=(-88.5256,-18.7758) -- time=16.859
# epoch=439 -- train_error=107.3255 -- valid_error=108.9211 -- cost(Rec,KL)=(-88.5244,-18.8011) -- time=16.153
# epoch=440 -- train_error=107.2548 -- valid_error=108.9600 -- cost(Rec,KL)=(-88.4758,-18.7790) -- time=15.805
# epoch=441 -- train_error=107.1997 -- valid_error=108.9601 -- cost(Rec,KL)=(-88.4201,-18.7796) -- time=16.437
# epoch=442 -- train_error=107.3786 -- valid_error=109.3474 -- cost(Rec,KL)=(-88.5633,-18.8153) -- time=17.332
# epoch=443 -- train_error=107.4078 -- valid_error=109.2030 -- cost(Rec,KL)=(-88.6220,-18.7857) -- time=16.520
# epoch=444 -- train_error=107.2999 -- valid_error=109.0250 -- cost(Rec,KL)=(-88.4853,-18.8146) -- time=15.772
# epoch=445 -- train_error=107.1672 -- valid_error=108.8851 -- cost(Rec,KL)=(-88.3493,-18.8179) -- time=16.676
# epoch=446 -- train_error=107.1064 -- valid_error=109.1154 -- cost(Rec,KL)=(-88.3181,-18.7883) -- time=15.224
# epoch=447 -- train_error=107.0743 -- valid_error=108.8942 -- cost(Rec,KL)=(-88.2890,-18.7853) -- time=15.124
# epoch=448 -- train_error=107.1356 -- valid_error=108.9202 -- cost(Rec,KL)=(-88.3318,-18.8038) -- time=16.481
# epoch=449 -- train_error=107.1045 -- valid_error=108.7053 -- cost(Rec,KL)=(-88.3127,-18.7918) -- time=17.644
# epoch=450 -- train_error=106.9770 -- valid_error=108.8122 -- cost(Rec,KL)=(-88.1822,-18.7948) -- time=15.393
# epoch=451 -- train_error=106.9256 -- valid_error=108.7385 -- cost(Rec,KL)=(-88.1317,-18.7939) -- time=16.335
# epoch=452 -- train_error=106.9269 -- valid_error=108.4329 -- cost(Rec,KL)=(-88.1243,-18.8026) -- time=16.698
# epoch=453 -- train_error=106.9150 -- valid_error=108.9639 -- cost(Rec,KL)=(-88.1150,-18.8000) -- time=15.653
# epoch=454 -- train_error=107.0739 -- valid_error=108.9909 -- cost(Rec,KL)=(-88.2749,-18.7990) -- time=15.834
# epoch=455 -- train_error=107.0957 -- valid_error=109.1644 -- cost(Rec,KL)=(-88.2811,-18.8146) -- time=15.836
# epoch=456 -- train_error=107.0596 -- valid_error=108.7899 -- cost(Rec,KL)=(-88.2443,-18.8152) -- time=15.970
# epoch=457 -- train_error=107.0811 -- valid_error=109.3573 -- cost(Rec,KL)=(-88.2396,-18.8415) -- time=16.160
# epoch=458 -- train_error=107.3631 -- valid_error=109.1483 -- cost(Rec,KL)=(-88.5518,-18.8112) -- time=15.077
# epoch=459 -- train_error=107.0388 -- valid_error=108.6446 -- cost(Rec,KL)=(-88.2188,-18.8200) -- time=15.277
# epoch=460 -- train_error=106.7779 -- valid_error=108.4526 -- cost(Rec,KL)=(-87.9596,-18.8184) -- time=17.045
# epoch=461 -- train_error=106.6455 -- valid_error=108.5408 -- cost(Rec,KL)=(-87.8337,-18.8118) -- time=15.313
# epoch=462 -- train_error=106.6061 -- valid_error=108.5926 -- cost(Rec,KL)=(-87.7919,-18.8143) -- time=15.911
# epoch=463 -- train_error=106.6507 -- valid_error=108.5819 -- cost(Rec,KL)=(-87.8238,-18.8269) -- time=16.226
# epoch=464 -- train_error=106.7550 -- valid_error=108.5318 -- cost(Rec,KL)=(-87.9350,-18.8200) -- time=16.889
# epoch=465 -- train_error=106.7601 -- valid_error=108.6750 -- cost(Rec,KL)=(-87.9311,-18.8290) -- time=15.908
# epoch=466 -- train_error=106.8192 -- valid_error=108.8471 -- cost(Rec,KL)=(-88.0094,-18.8098) -- time=16.022
# epoch=467 -- train_error=107.0895 -- valid_error=108.9080 -- cost(Rec,KL)=(-88.2576,-18.8319) -- time=18.230
# epoch=468 -- train_error=106.9487 -- valid_error=108.5771 -- cost(Rec,KL)=(-88.0927,-18.8560) -- time=16.541
# epoch=469 -- train_error=106.8729 -- valid_error=108.3228 -- cost(Rec,KL)=(-88.0507,-18.8222) -- time=15.809
# epoch=470 -- train_error=106.7245 -- valid_error=108.3818 -- cost(Rec,KL)=(-87.8930,-18.8315) -- time=17.056
# epoch=471 -- train_error=106.6400 -- valid_error=108.6873 -- cost(Rec,KL)=(-87.8191,-18.8209) -- time=14.706
# epoch=472 -- train_error=106.4670 -- valid_error=108.3003 -- cost(Rec,KL)=(-87.6192,-18.8478) -- time=16.163
# epoch=473 -- train_error=106.4027 -- valid_error=108.2350 -- cost(Rec,KL)=(-87.5730,-18.8297) -- time=16.736
# epoch=474 -- train_error=106.8433 -- valid_error=109.1445 -- cost(Rec,KL)=(-88.0078,-18.8355) -- time=16.001
# epoch=475 -- train_error=106.9696 -- valid_error=108.7068 -- cost(Rec,KL)=(-88.1144,-18.8552) -- time=16.617
# epoch=476 -- train_error=106.5637 -- valid_error=108.2748 -- cost(Rec,KL)=(-87.7115,-18.8522) -- time=15.881
# epoch=477 -- train_error=106.3912 -- valid_error=108.2144 -- cost(Rec,KL)=(-87.5554,-18.8358) -- time=14.407
# epoch=478 -- train_error=106.5378 -- valid_error=109.1633 -- cost(Rec,KL)=(-87.6911,-18.8466) -- time=14.984
# epoch=479 -- train_error=106.7651 -- valid_error=108.6222 -- cost(Rec,KL)=(-87.9342,-18.8309) -- time=15.933
# epoch=480 -- train_error=106.5088 -- valid_error=108.4275 -- cost(Rec,KL)=(-87.6412,-18.8676) -- time=16.218
# epoch=481 -- train_error=106.3911 -- valid_error=108.3542 -- cost(Rec,KL)=(-87.5415,-18.8496) -- time=14.776
# epoch=482 -- train_error=106.4128 -- valid_error=108.5546 -- cost(Rec,KL)=(-87.5336,-18.8792) -- time=16.087
# epoch=483 -- train_error=106.7324 -- valid_error=108.6456 -- cost(Rec,KL)=(-87.8838,-18.8486) -- time=15.593
# epoch=484 -- train_error=106.7766 -- valid_error=108.2705 -- cost(Rec,KL)=(-87.9090,-18.8676) -- time=16.771
# epoch=485 -- train_error=106.4339 -- valid_error=108.3954 -- cost(Rec,KL)=(-87.6086,-18.8253) -- time=16.039
# epoch=486 -- train_error=106.2895 -- valid_error=108.3325 -- cost(Rec,KL)=(-87.4217,-18.8678) -- time=16.284
# epoch=487 -- train_error=106.3353 -- valid_error=108.2293 -- cost(Rec,KL)=(-87.4860,-18.8493) -- time=16.257
# epoch=488 -- train_error=106.3049 -- valid_error=108.2904 -- cost(Rec,KL)=(-87.4672,-18.8377) -- time=15.540
# epoch=489 -- train_error=106.4963 -- valid_error=108.8331 -- cost(Rec,KL)=(-87.6454,-18.8509) -- time=10.543
# epoch=490 -- train_error=106.5144 -- valid_error=108.6462 -- cost(Rec,KL)=(-87.6432,-18.8712) -- time=10.768
# epoch=491 -- train_error=106.3746 -- valid_error=108.1778 -- cost(Rec,KL)=(-87.4988,-18.8757) -- time=10.682
# epoch=492 -- train_error=106.3200 -- valid_error=108.7658 -- cost(Rec,KL)=(-87.4683,-18.8517) -- time=10.505
# epoch=493 -- train_error=106.5780 -- valid_error=108.6798 -- cost(Rec,KL)=(-87.6723,-18.9057) -- time=10.460
# epoch=494 -- train_error=106.4385 -- valid_error=108.2482 -- cost(Rec,KL)=(-87.5635,-18.8750) -- time=10.522
# epoch=495 -- train_error=106.2697 -- valid_error=108.1400 -- cost(Rec,KL)=(-87.3914,-18.8783) -- time=10.486
# epoch=496 -- train_error=106.1199 -- valid_error=108.1152 -- cost(Rec,KL)=(-87.2556,-18.8643) -- time=10.507
# epoch=497 -- train_error=106.1765 -- valid_error=108.0206 -- cost(Rec,KL)=(-87.3034,-18.8731) -- time=10.543
# epoch=498 -- train_error=106.2564 -- valid_error=107.9120 -- cost(Rec,KL)=(-87.3842,-18.8722) -- time=10.527
# epoch=499 -- train_error=106.2964 -- valid_error=108.0435 -- cost(Rec,KL)=(-87.4282,-18.8683) -- time=10.302

# %%
train_y_vals = train_y.eval()
error, train_rec, train_mu,train_logvar = vae_predict(train_x.get_value())

plot_2d_proj(train_mu, train_y_vals,"latent space for training set - mean")
plot_2d_proj(np.exp(0.5*train_logvar), train_y_vals,"latent space for training set- variance")

# %%
train_data = train_x.get_value()
plot_act_rec(train_data[mini_batch,:][:20,:],rec[:20,:])

# %%
error, rec, latent_mu, latent_logvar = vae_predict(train_x.get_value())
plot_2d_proj(latent_mu, train_y.eval(),"training set : latent space for mean")
plot_2d_proj(np.exp(0.5*latent_logvar), train_y.eval(),"training set : latent space for variance")

# %%
actual = train_x.get_value()[:20,:]
_,recons,_,_ = vae_predict(actual)
plot_act_rec(actual,recons,"traning set : samples")

# %%
error, rec, latent_mu, latent_logvar = vae_predict(valid_x.get_value())
plot_2d_proj(latent_mu, valid_y.eval(),"validation set : latent space for mean")
plot_2d_proj(np.exp(0.5*latent_logvar), valid_y.eval(),"validation set : latent space for variance")

# %%
actual = valid_x.get_value()[:20,:]
_,recons,_,_ = vae_predict(actual)
plot_act_rec(actual,recons,"validation set : samples")

# %%
error, rec, latent_mu, latent_logvar = vae_predict(test_x.get_value())
plot_2d_proj(latent_mu, test_y.eval(),"test set : latent space for mean")
plot_2d_proj(np.exp(0.5*latent_logvar), test_y.eval(),"test set : latent space for variance")

# %%
actual = train_x.get_value()[:20,:]
_,recons,_,_ = vae_predict(actual)
plot_act_rec(actual,recons,"train set : samples")

# %%
param_dict = {}
for par in params:
    param_dict.update({par.name:par.get_value()})

f = open('vae_10ld.save', 'wb')
pickle.dump(param_dict, f, protocol=pickle.HIGHEST_PROTOCOL)
f.close()

# %%
W1.get_value()
# Out:
# array([[ 0.04579249, -0.05265942,  0.02310486, ...,  0.03005032,
#         -0.02835881, -0.02330826],
#        [-0.00252168, -0.05316192,  0.03537482, ...,  0.02208587,
#          0.05976836, -0.0236217 ],
#        [ 0.06526572,  0.04270278,  0.04203742, ...,  0.01416105,
#         -0.01265514,  0.03511151],
#        ...,
#        [-0.03886236,  0.02786711, -0.0632353 , ..., -0.06755926,
#          0.04096094,  0.00011781],
#        [ 0.04912662, -0.00965109,  0.06309115, ..., -0.05391626,
#          0.05795423, -0.04073723],
#        [-0.04839214, -0.05140843, -0.0601747 , ..., -0.01527713,
#         -0.03175928, -0.05195673]])
